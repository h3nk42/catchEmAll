# %%
import sys
import loadOptions as lp


def loadFiles(version, arena):

    file_path     = "../data/"
    list_of_files = []
    arena_list    = ["arena-1",
                     "arena-2",
                     "arena-3",
                     "arena-4",
                     "arena-5",
                     "arena-6",
                     "arena-7",
                     "arena-8",
                     "arena-9",]

    file_path = getVersionPath(version, file_path)

    if file_path == None:
        
        sys.exit(1)

    else:
        
        if arena in arena_list:
            
            file_path        += "/" + arena + "/"
            encounter_pokemon = file_path + "EncounterablePokemon.csv"
            pokemon_of_leader = file_path + "LeaderPokemon.csv"
            arena_leader = file_path + "ArenaLeader.csv"
            move_of_in        = file_path + "MovesOfInterest.csv"

            list_of_files.append(encounter_pokemon)
            list_of_files.append(pokemon_of_leader)
            list_of_files.append(arena_leader)
            list_of_files.append(move_of_in)
            
        else:

            print("[-] Arena not found...")



    return list_of_files

def getVersionPath(version, file_path):

    if version == "red":

        file_path += "red"

        return file_path

    elif version == "blue":

        file_path += "blue"
    
        return file_path

    else:

        print("[-] Version not found...")

# %%
csvPaths = loadFiles("blue", "arena-9")

# %%
csvPaths
# Out:
# ['../data/blue/arena-9/EncounterablePokemon.csv',
#  '../data/blue/arena-9/LeaderPokemon.csv',
#  '../data/blue/arena-9/ArenaLeader.csv',
#  '../data/blue/arena-9/MovesOfInterest.csv']

# %%
# SETUP DATAFRAMES
encounterable_pokemonTable = pd.read_csv(csvPaths[0])
encounterable_pokemonParsed = []

for row in encounterable_pokemonTable.values.tolist():
    moves = row[2]
    moves = moves.replace("'", "\"") 
    moves = json.loads(moves)
    row[2] = moves
    encounterable_pokemonParsed.append(row)
    
leader_pokemon =  pd.read_csv(csvPaths[1])
arena_leader = pd.read_csv(csvPaths[2])
moves_of_interest = pd.read_csv(csvPaths[3])

## extracted Variables from DATAFRAME
averageLevel = arena_leader['averageLevel'][0]

## Variables for each Arena
arena1_Options = lp.loadOption('arena-6')

# %%
encounterable_pokemonParsed
# Out:
# [[0,
#   'pidgey',
#   [{'name': 'gust', 'levelLearnedAt': 1},
#    {'name': 'sand-attack', 'levelLearnedAt': 5},
#    {'name': 'quick-attack', 'levelLearnedAt': 12},
#    {'name': 'whirlwind', 'levelLearnedAt': 19},
#    {'name': 'wing-attack', 'levelLearnedAt': 28},
#    {'name': 'agility', 'levelLearnedAt': 36},
#    {'name': 'mirror-move', 'levelLearnedAt': 44}],
#   'walk',
#   nan,
#   "['fly']",
#   "['whirlwind', 'bide', 'rest', 'reflect', 'razor-wind', 'double-edge', 'substitute', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic', 'sky-attack']"],
#  [1,
#   'rattata',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'tail-whip', 'levelLearnedAt': 1},
#    {'name': 'quick-attack', 'levelLearnedAt': 7},
#    {'name': 'hyper-fang', 'levelLearnedAt': 14},
#    {'name': 'focus-energy', 'levelLearnedAt': 23},
#    {'name': 'super-fang', 'levelLearnedAt': 34}],
#   'walk',
#   nan,
#   "['cut']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'thunder-wave', 'dig', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [2,
#   'caterpie',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'string-shot', 'levelLearnedAt': 1}],
#   'walk',
#   nan,
#   '[]',
#   '[]'],
#  [3,
#   'metapod',
#   [{'name': 'harden', 'levelLearnedAt': 1}],
#   'walk',
#   nan,
#   '[]',
#   '[]'],
#  [4,
#   'weedle',
#   [{'name': 'poison-sting', 'levelLearnedAt': 1},
#    {'name': 'string-shot', 'levelLearnedAt': 1}],
#   'walk',
#   nan,
#   '[]',
#   '[]'],
#  [5,
#   'kakuna',
#   [{'name': 'harden', 'levelLearnedAt': 1}],
#   'walk',
#   nan,
#   '[]',
#   '[]'],
#  [6,
#   'pikachu',
#   [{'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'thunder-shock', 'levelLearnedAt': 1},
#    {'name': 'thunder-wave', 'levelLearnedAt': 9},
#    {'name': 'quick-attack', 'levelLearnedAt': 16},
#    {'name': 'swift', 'levelLearnedAt': 26},
#    {'name': 'agility', 'levelLearnedAt': 33},
#    {'name': 'thunder', 'levelLearnedAt': 43}],
#   'walk',
#   nan,
#   "['flash', 'surf', 'strength']",
#   "['mega-punch', 'bide', 'thunder', 'thunder-wave', 'seismic-toss', 'dig', 'thunderbolt', 'body-slam', 'rest', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'swift', 'rage', 'toxic', 'take-down', 'mimic']"],
#  [7,
#   'spearow',
#   [{'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'peck', 'levelLearnedAt': 1},
#    {'name': 'leer', 'levelLearnedAt': 9},
#    {'name': 'fury-attack', 'levelLearnedAt': 15},
#    {'name': 'mirror-move', 'levelLearnedAt': 22},
#    {'name': 'drill-peck', 'levelLearnedAt': 29},
#    {'name': 'agility', 'levelLearnedAt': 36}],
#   'walk',
#   nan,
#   "['fly']",
#   "['whirlwind', 'bide', 'rest', 'tri-attack', 'razor-wind', 'double-edge', 'substitute', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic', 'sky-attack']"],
#  [8,
#   'nidoran-f',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'scratch', 'levelLearnedAt': 8},
#    {'name': 'poison-sting', 'levelLearnedAt': 14},
#    {'name': 'tail-whip', 'levelLearnedAt': 21},
#    {'name': 'bite', 'levelLearnedAt': 29},
#    {'name': 'fury-swipes', 'levelLearnedAt': 36},
#    {'name': 'double-kick', 'levelLearnedAt': 43}],
#   'walk',
#   nan,
#   "['cut', 'strength']",
#   "['bide', 'thunder', 'dig', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'reflect', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [9,
#   'nidoran-m',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'leer', 'levelLearnedAt': 1},
#    {'name': 'horn-attack', 'levelLearnedAt': 8},
#    {'name': 'poison-sting', 'levelLearnedAt': 14},
#    {'name': 'focus-energy', 'levelLearnedAt': 21},
#    {'name': 'fury-attack', 'levelLearnedAt': 29},
#    {'name': 'horn-drill', 'levelLearnedAt': 36},
#    {'name': 'double-kick', 'levelLearnedAt': 43}],
#   'walk',
#   nan,
#   "['cut', 'strength']",
#   "['bide', 'thunder', 'dig', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'reflect', 'horn-drill', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [10,
#   'poliwag',
#   [{'name': 'bubble', 'levelLearnedAt': 1},
#    {'name': 'hypnosis', 'levelLearnedAt': 16},
#    {'name': 'water-gun', 'levelLearnedAt': 19},
#    {'name': 'double-slap', 'levelLearnedAt': 25},
#    {'name': 'body-slam', 'levelLearnedAt': 31},
#    {'name': 'amnesia', 'levelLearnedAt': 38},
#    {'name': 'hydro-pump', 'levelLearnedAt': 45}],
#   'fishing',
#   nan,
#   "['surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'dig', 'body-slam', 'rest', 'ice-beam', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'psywave', 'blizzard', 'psychic', 'mimic']"],
#  [11,
#   'goldeen',
#   [{'name': 'tail-whip', 'levelLearnedAt': 1},
#    {'name': 'peck', 'levelLearnedAt': 1},
#    {'name': 'supersonic', 'levelLearnedAt': 19},
#    {'name': 'horn-attack', 'levelLearnedAt': 24},
#    {'name': 'fury-attack', 'levelLearnedAt': 30},
#    {'name': 'waterfall', 'levelLearnedAt': 37},
#    {'name': 'horn-drill', 'levelLearnedAt': 45},
#    {'name': 'agility', 'levelLearnedAt': 54}],
#   'fishing',
#   nan,
#   "['surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'body-slam', 'rest', 'ice-beam', 'horn-drill', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [12,
#   'magikarp',
#   [{'name': 'splash', 'levelLearnedAt': 1},
#    {'name': 'tackle', 'levelLearnedAt': 15}],
#   'fishing',
#   nan,
#   '[]',
#   '[]'],
#  [13,
#   'jigglypuff',
#   [{'name': 'sing', 'levelLearnedAt': 1},
#    {'name': 'pound', 'levelLearnedAt': 9},
#    {'name': 'disable', 'levelLearnedAt': 14},
#    {'name': 'defense-curl', 'levelLearnedAt': 19},
#    {'name': 'double-slap', 'levelLearnedAt': 24},
#    {'name': 'rest', 'levelLearnedAt': 29},
#    {'name': 'body-slam', 'levelLearnedAt': 34},
#    {'name': 'double-edge', 'levelLearnedAt': 39}],
#   'walk',
#   nan,
#   "['flash', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'thunder', 'thunder-wave', 'seismic-toss', 'dig', 'thunderbolt', 'body-slam', 'rest', 'teleport', 'ice-beam', 'tri-attack', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'dream-eater', 'rage', 'toxic', 'take-down', 'psywave', 'blizzard', 'solar-beam', 'psychic', 'mimic', 'fire-blast']"],
#  [14,
#   'clefairy',
#   [{'name': 'pound', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'sing', 'levelLearnedAt': 13},
#    {'name': 'double-slap', 'levelLearnedAt': 18},
#    {'name': 'minimize', 'levelLearnedAt': 24},
#    {'name': 'metronome', 'levelLearnedAt': 31},
#    {'name': 'defense-curl', 'levelLearnedAt': 39},
#    {'name': 'light-screen', 'levelLearnedAt': 48}],
#   'walk',
#   nan,
#   "['flash', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'thunder', 'thunder-wave', 'seismic-toss', 'dig', 'thunderbolt', 'body-slam', 'rest', 'teleport', 'ice-beam', 'tri-attack', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'soft-boiled', 'substitute', 'skull-bash', 'double-team', 'dream-eater', 'rage', 'toxic', 'take-down', 'psywave', 'blizzard', 'solar-beam', 'psychic', 'mimic', 'metronome', 'fire-blast']"],
#  [15,
#   'zubat',
#   [{'name': 'leech-life', 'levelLearnedAt': 1},
#    {'name': 'supersonic', 'levelLearnedAt': 10},
#    {'name': 'bite', 'levelLearnedAt': 15},
#    {'name': 'confuse-ray', 'levelLearnedAt': 21},
#    {'name': 'wing-attack', 'levelLearnedAt': 28},
#    {'name': 'haze', 'levelLearnedAt': 36}],
#   'walk',
#   nan,
#   "['fly']",
#   "['whirlwind', 'bide', 'rest', 'razor-wind', 'double-edge', 'substitute', 'mega-drain', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic']"],
#  [16,
#   'paras',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'stun-spore', 'levelLearnedAt': 13},
#    {'name': 'leech-life', 'levelLearnedAt': 20},
#    {'name': 'spore', 'levelLearnedAt': 27},
#    {'name': 'slash', 'levelLearnedAt': 34},
#    {'name': 'growth', 'levelLearnedAt': 41}],
#   'walk',
#   nan,
#   "['cut', 'flash']",
#   "['bide', 'dig', 'body-slam', 'rest', 'reflect', 'counter', 'double-edge', 'substitute', 'mega-drain', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'solar-beam', 'mimic']"],
#  [17,
#   'geodude',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'defense-curl', 'levelLearnedAt': 11},
#    {'name': 'rock-throw', 'levelLearnedAt': 16},
#    {'name': 'self-destruct', 'levelLearnedAt': 21},
#    {'name': 'harden', 'levelLearnedAt': 26},
#    {'name': 'earthquake', 'levelLearnedAt': 31},
#    {'name': 'explosion', 'levelLearnedAt': 36}],
#   'walk',
#   nan,
#   "['strength']",
#   "['mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'rock-slide', 'submission', 'counter', 'double-edge', 'substitute', 'double-team', 'rage', 'toxic', 'self-destruct', 'take-down', 'earthquake', 'mimic', 'metronome', 'fire-blast', 'fissure', 'explosion']"],
#  [18,
#   'sandshrew',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'sand-attack', 'levelLearnedAt': 10},
#    {'name': 'slash', 'levelLearnedAt': 17},
#    {'name': 'poison-sting', 'levelLearnedAt': 24},
#    {'name': 'swift', 'levelLearnedAt': 31},
#    {'name': 'fury-swipes', 'levelLearnedAt': 38}],
#   'walk',
#   nan,
#   "['cut', 'strength']",
#   "['bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'rock-slide', 'submission', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'swords-dance', 'earthquake', 'mimic', 'fissure']"],
#  [19,
#   'psyduck',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'tail-whip', 'levelLearnedAt': 28},
#    {'name': 'disable', 'levelLearnedAt': 31},
#    {'name': 'confusion', 'levelLearnedAt': 36},
#    {'name': 'fury-swipes', 'levelLearnedAt': 43},
#    {'name': 'hydro-pump', 'levelLearnedAt': 52}],
#   'walk',
#   nan,
#   "['flash', 'surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'ice-beam', 'mega-kick', 'submission', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'psychic', 'mimic']"],
#  [20,
#   'abra',
#   [{'name': 'teleport', 'levelLearnedAt': 1}],
#   'walk',
#   nan,
#   "['flash']",
#   "['mega-punch', 'bide', 'thunder-wave', 'seismic-toss', 'body-slam', 'rest', 'teleport', 'tri-attack', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'dream-eater', 'rage', 'toxic', 'take-down', 'psywave', 'psychic', 'mimic', 'metronome']"],
#  [21,
#   'bellsprout',
#   [{'name': 'vine-whip', 'levelLearnedAt': 1},
#    {'name': 'growth', 'levelLearnedAt': 1},
#    {'name': 'wrap', 'levelLearnedAt': 13},
#    {'name': 'poison-powder', 'levelLearnedAt': 15},
#    {'name': 'sleep-powder', 'levelLearnedAt': 18},
#    {'name': 'stun-spore', 'levelLearnedAt': 21},
#    {'name': 'acid', 'levelLearnedAt': 26},
#    {'name': 'razor-leaf', 'levelLearnedAt': 33},
#    {'name': 'slam', 'levelLearnedAt': 42}],
#   'walk',
#   nan,
#   "['cut', 'flash']",
#   "['bide', 'rest', 'reflect', 'double-edge', 'substitute', 'mega-drain', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'solar-beam', 'mimic']"],
#  [22,
#   'krabby',
#   [{'name': 'leer', 'levelLearnedAt': 1},
#    {'name': 'bubble', 'levelLearnedAt': 1},
#    {'name': 'vise-grip', 'levelLearnedAt': 20},
#    {'name': 'guillotine', 'levelLearnedAt': 25},
#    {'name': 'stomp', 'levelLearnedAt': 30},
#    {'name': 'crabhammer', 'levelLearnedAt': 35},
#    {'name': 'harden', 'levelLearnedAt': 40}],
#   'fishing',
#   nan,
#   "['cut', 'surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'bide', 'dig', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'double-edge', 'substitute', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'blizzard', 'mimic']"],
#  [23,
#   'shellder',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'withdraw', 'levelLearnedAt': 1},
#    {'name': 'supersonic', 'levelLearnedAt': 18},
#    {'name': 'clamp', 'levelLearnedAt': 23},
#    {'name': 'aurora-beam', 'levelLearnedAt': 30},
#    {'name': 'leer', 'levelLearnedAt': 39},
#    {'name': 'ice-beam', 'levelLearnedAt': 50}],
#   'walk',
#   nan,
#   "['surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'rest', 'teleport', 'ice-beam', 'tri-attack', 'reflect', 'double-edge', 'substitute', 'double-team', 'swift', 'rage', 'toxic', 'self-destruct', 'take-down', 'blizzard', 'mimic', 'explosion']"],
#  [24,
#   'drowzee',
#   [{'name': 'pound', 'levelLearnedAt': 1},
#    {'name': 'hypnosis', 'levelLearnedAt': 1},
#    {'name': 'disable', 'levelLearnedAt': 12},
#    {'name': 'confusion', 'levelLearnedAt': 17},
#    {'name': 'headbutt', 'levelLearnedAt': 24},
#    {'name': 'poison-gas', 'levelLearnedAt': 29},
#    {'name': 'psychic', 'levelLearnedAt': 32},
#    {'name': 'meditate', 'levelLearnedAt': 37}],
#   'walk',
#   nan,
#   "['flash']",
#   "['mega-punch', 'bide', 'thunder-wave', 'seismic-toss', 'body-slam', 'rest', 'teleport', 'tri-attack', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'dream-eater', 'rage', 'toxic', 'take-down', 'psywave', 'psychic', 'mimic', 'metronome']"],
#  [25,
#   'diglett',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 15},
#    {'name': 'dig', 'levelLearnedAt': 19},
#    {'name': 'sand-attack', 'levelLearnedAt': 24},
#    {'name': 'slash', 'levelLearnedAt': 31},
#    {'name': 'earthquake', 'levelLearnedAt': 40}],
#   'walk',
#   nan,
#   "['cut']",
#   "['bide', 'dig', 'body-slam', 'rest', 'rock-slide', 'double-edge', 'substitute', 'double-team', 'rage', 'toxic', 'take-down', 'earthquake', 'mimic', 'fissure']"],
#  [26,
#   'dugtrio',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 15},
#    {'name': 'dig', 'levelLearnedAt': 19},
#    {'name': 'sand-attack', 'levelLearnedAt': 24},
#    {'name': 'slash', 'levelLearnedAt': 35},
#    {'name': 'earthquake', 'levelLearnedAt': 47}],
#   'walk',
#   nan,
#   "['cut']",
#   "['bide', 'dig', 'body-slam', 'rest', 'rock-slide', 'tri-attack', 'double-edge', 'hyper-beam', 'substitute', 'double-team', 'rage', 'toxic', 'take-down', 'earthquake', 'mimic', 'fissure']"],
#  [27,
#   'meowth',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'bite', 'levelLearnedAt': 12},
#    {'name': 'pay-day', 'levelLearnedAt': 17},
#    {'name': 'screech', 'levelLearnedAt': 24},
#    {'name': 'fury-swipes', 'levelLearnedAt': 33},
#    {'name': 'slash', 'levelLearnedAt': 44}],
#   'walk',
#   nan,
#   "['cut', 'flash']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'dig', 'thunderbolt', 'body-slam', 'rest', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'swift', 'dream-eater', 'rage', 'toxic', 'take-down', 'mimic']"],
#  [28,
#   'poliwhirl',
#   [{'name': 'bubble', 'levelLearnedAt': 1},
#    {'name': 'hypnosis', 'levelLearnedAt': 16},
#    {'name': 'water-gun', 'levelLearnedAt': 19},
#    {'name': 'double-slap', 'levelLearnedAt': 26},
#    {'name': 'body-slam', 'levelLearnedAt': 33},
#    {'name': 'amnesia', 'levelLearnedAt': 41},
#    {'name': 'hydro-pump', 'levelLearnedAt': 49}],
#   'walk',
#   nan,
#   "['surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'ice-beam', 'mega-kick', 'submission', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'earthquake', 'psywave', 'blizzard', 'psychic', 'mimic', 'metronome', 'fissure']"],
#  [29,
#   'slowpoke',
#   [{'name': 'confusion', 'levelLearnedAt': 1},
#    {'name': 'disable', 'levelLearnedAt': 18},
#    {'name': 'headbutt', 'levelLearnedAt': 22},
#    {'name': 'growl', 'levelLearnedAt': 27},
#    {'name': 'water-gun', 'levelLearnedAt': 33},
#    {'name': 'amnesia', 'levelLearnedAt': 40},
#    {'name': 'psychic', 'levelLearnedAt': 48}],
#   'walk',
#   nan,
#   "['flash', 'surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder-wave', 'dig', 'body-slam', 'rest', 'teleport', 'ice-beam', 'tri-attack', 'reflect', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'swift', 'dream-eater', 'rage', 'toxic', 'take-down', 'earthquake', 'psywave', 'blizzard', 'psychic', 'mimic', 'fire-blast', 'fissure']"],
#  [30,
#   'voltorb',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'screech', 'levelLearnedAt': 1},
#    {'name': 'sonic-boom', 'levelLearnedAt': 17},
#    {'name': 'self-destruct', 'levelLearnedAt': 22},
#    {'name': 'light-screen', 'levelLearnedAt': 29},
#    {'name': 'swift', 'levelLearnedAt': 36},
#    {'name': 'explosion', 'levelLearnedAt': 43}],
#   'walk',
#   nan,
#   "['flash']",
#   "['bide', 'thunder', 'thunder-wave', 'thunderbolt', 'rest', 'teleport', 'reflect', 'substitute', 'double-team', 'swift', 'rage', 'toxic', 'self-destruct', 'take-down', 'mimic', 'explosion']"],
#  [31,
#   'machop',
#   [{'name': 'karate-chop', 'levelLearnedAt': 1},
#    {'name': 'low-kick', 'levelLearnedAt': 20},
#    {'name': 'leer', 'levelLearnedAt': 25},
#    {'name': 'focus-energy', 'levelLearnedAt': 32},
#    {'name': 'seismic-toss', 'levelLearnedAt': 39},
#    {'name': 'submission', 'levelLearnedAt': 46}],
#   'walk',
#   nan,
#   "['strength']",
#   "['mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'rock-slide', 'mega-kick', 'submission', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'earthquake', 'mimic', 'metronome', 'fire-blast', 'fissure']"],
#  [32,
#   'onix',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'screech', 'levelLearnedAt': 1},
#    {'name': 'bind', 'levelLearnedAt': 15},
#    {'name': 'rock-throw', 'levelLearnedAt': 19},
#    {'name': 'rage', 'levelLearnedAt': 25},
#    {'name': 'slam', 'levelLearnedAt': 33},
#    {'name': 'harden', 'levelLearnedAt': 43}],
#   'walk',
#   nan,
#   "['strength']",
#   "['bide', 'dig', 'body-slam', 'rest', 'rock-slide', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'self-destruct', 'take-down', 'earthquake', 'mimic', 'fissure', 'explosion']"],
#  [33,
#   'vulpix',
#   [{'name': 'tail-whip', 'levelLearnedAt': 1},
#    {'name': 'ember', 'levelLearnedAt': 1},
#    {'name': 'quick-attack', 'levelLearnedAt': 16},
#    {'name': 'roar', 'levelLearnedAt': 21},
#    {'name': 'confuse-ray', 'levelLearnedAt': 28},
#    {'name': 'flamethrower', 'levelLearnedAt': 35},
#    {'name': 'fire-spin', 'levelLearnedAt': 42}],
#   'walk',
#   nan,
#   '[]',
#   "['bide', 'dig', 'body-slam', 'rest', 'reflect', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic', 'fire-blast']"],
#  [34,
#   'gastly',
#   [{'name': 'night-shade', 'levelLearnedAt': 1},
#    {'name': 'confuse-ray', 'levelLearnedAt': 1},
#    {'name': 'lick', 'levelLearnedAt': 1},
#    {'name': 'hypnosis', 'levelLearnedAt': 27},
#    {'name': 'dream-eater', 'levelLearnedAt': 35}],
#   'walk',
#   nan,
#   '[]',
#   "['bide', 'thunder', 'thunderbolt', 'rest', 'substitute', 'mega-drain', 'double-team', 'dream-eater', 'rage', 'toxic', 'self-destruct', 'psywave', 'psychic', 'mimic', 'explosion']"],
#  [35,
#   'haunter',
#   [{'name': 'night-shade', 'levelLearnedAt': 1},
#    {'name': 'confuse-ray', 'levelLearnedAt': 1},
#    {'name': 'lick', 'levelLearnedAt': 1},
#    {'name': 'hypnosis', 'levelLearnedAt': 29},
#    {'name': 'dream-eater', 'levelLearnedAt': 38}],
#   'walk',
#   nan,
#   '[]',
#   "['bide', 'thunder', 'thunderbolt', 'rest', 'substitute', 'mega-drain', 'double-team', 'dream-eater', 'rage', 'toxic', 'self-destruct', 'psywave', 'psychic', 'mimic', 'explosion']"],
#  [36,
#   'cubone',
#   [{'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'bone-club', 'levelLearnedAt': 1},
#    {'name': 'leer', 'levelLearnedAt': 25},
#    {'name': 'focus-energy', 'levelLearnedAt': 31},
#    {'name': 'thrash', 'levelLearnedAt': 38},
#    {'name': 'bonemerang', 'levelLearnedAt': 43},
#    {'name': 'rage', 'levelLearnedAt': 46}],
#   'walk',
#   nan,
#   "['strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'mega-kick', 'submission', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'earthquake', 'blizzard', 'mimic', 'fire-blast', 'fissure']"],
#  [37,
#   'venonat',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'disable', 'levelLearnedAt': 1},
#    {'name': 'poison-powder', 'levelLearnedAt': 24},
#    {'name': 'leech-life', 'levelLearnedAt': 27},
#    {'name': 'stun-spore', 'levelLearnedAt': 30},
#    {'name': 'psybeam', 'levelLearnedAt': 35},
#    {'name': 'sleep-powder', 'levelLearnedAt': 38},
#    {'name': 'psychic', 'levelLearnedAt': 43}],
#   'walk',
#   nan,
#   "['flash']",
#   "['bide', 'rest', 'reflect', 'double-edge', 'substitute', 'mega-drain', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'psywave', 'solar-beam', 'psychic', 'mimic']"],
#  [38,
#   'weepinbell',
#   [{'name': 'vine-whip', 'levelLearnedAt': 1},
#    {'name': 'growth', 'levelLearnedAt': 1},
#    {'name': 'wrap', 'levelLearnedAt': 13},
#    {'name': 'poison-powder', 'levelLearnedAt': 15},
#    {'name': 'sleep-powder', 'levelLearnedAt': 18},
#    {'name': 'stun-spore', 'levelLearnedAt': 23},
#    {'name': 'acid', 'levelLearnedAt': 29},
#    {'name': 'razor-leaf', 'levelLearnedAt': 38},
#    {'name': 'slam', 'levelLearnedAt': 49}],
#   'walk',
#   nan,
#   "['cut', 'flash']",
#   "['bide', 'rest', 'reflect', 'double-edge', 'substitute', 'mega-drain', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'solar-beam', 'mimic']"],
#  [39,
#   'tentacool',
#   [{'name': 'acid', 'levelLearnedAt': 1},
#    {'name': 'supersonic', 'levelLearnedAt': 7},
#    {'name': 'wrap', 'levelLearnedAt': 13},
#    {'name': 'poison-sting', 'levelLearnedAt': 18},
#    {'name': 'water-gun', 'levelLearnedAt': 22},
#    {'name': 'constrict', 'levelLearnedAt': 27},
#    {'name': 'barrier', 'levelLearnedAt': 33},
#    {'name': 'screech', 'levelLearnedAt': 40},
#    {'name': 'hydro-pump', 'levelLearnedAt': 48}],
#   'fishing',
#   nan,
#   "['cut', 'surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'rest', 'ice-beam', 'reflect', 'double-edge', 'substitute', 'mega-drain', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'blizzard', 'mimic']"],
#  [40,
#   'snorlax',
#   [{'name': 'headbutt', 'levelLearnedAt': 1},
#    {'name': 'amnesia', 'levelLearnedAt': 1},
#    {'name': 'rest', 'levelLearnedAt': 1},
#    {'name': 'body-slam', 'levelLearnedAt': 35},
#    {'name': 'harden', 'levelLearnedAt': 41},
#    {'name': 'double-edge', 'levelLearnedAt': 48},
#    {'name': 'hyper-beam', 'levelLearnedAt': 56}],
#   'walk',
#   nan,
#   "['surf', 'strength']",
#   "['bubble-beam', 'whirlwind', 'water-gun', 'mega-punch', 'bide', 'thunder', 'seismic-toss', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'rage', 'toxic', 'self-destruct', 'take-down', 'earthquake', 'psywave', 'blizzard', 'solar-beam', 'psychic', 'mimic', 'metronome', 'fire-blast', 'fissure']"],
#  [41,
#   'ditto',
#   [{'name': 'transform', 'levelLearnedAt': 1}],
#   'walk',
#   nan,
#   '[]',
#   '[]'],
#  [42,
#   'pidgeotto',
#   [{'name': 'gust', 'levelLearnedAt': 1},
#    {'name': 'sand-attack', 'levelLearnedAt': 5},
#    {'name': 'quick-attack', 'levelLearnedAt': 12},
#    {'name': 'whirlwind', 'levelLearnedAt': 21},
#    {'name': 'wing-attack', 'levelLearnedAt': 31},
#    {'name': 'agility', 'levelLearnedAt': 40},
#    {'name': 'mirror-move', 'levelLearnedAt': 49}],
#   'walk',
#   nan,
#   "['fly']",
#   "['whirlwind', 'bide', 'rest', 'reflect', 'razor-wind', 'double-edge', 'substitute', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic', 'sky-attack']"],
#  [43,
#   'nidorina',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'scratch', 'levelLearnedAt': 8},
#    {'name': 'poison-sting', 'levelLearnedAt': 14},
#    {'name': 'tail-whip', 'levelLearnedAt': 23},
#    {'name': 'bite', 'levelLearnedAt': 32},
#    {'name': 'fury-swipes', 'levelLearnedAt': 41},
#    {'name': 'double-kick', 'levelLearnedAt': 50}],
#   'walk',
#   nan,
#   "['cut', 'strength']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'dig', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'reflect', 'horn-drill', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [44,
#   'nidorino',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'leer', 'levelLearnedAt': 1},
#    {'name': 'horn-attack', 'levelLearnedAt': 8},
#    {'name': 'poison-sting', 'levelLearnedAt': 14},
#    {'name': 'focus-energy', 'levelLearnedAt': 23},
#    {'name': 'fury-attack', 'levelLearnedAt': 32},
#    {'name': 'horn-drill', 'levelLearnedAt': 41},
#    {'name': 'double-kick', 'levelLearnedAt': 50}],
#   'walk',
#   nan,
#   "['cut', 'strength']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'dig', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'reflect', 'horn-drill', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [45,
#   'parasect',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'stun-spore', 'levelLearnedAt': 13},
#    {'name': 'leech-life', 'levelLearnedAt': 20},
#    {'name': 'spore', 'levelLearnedAt': 30},
#    {'name': 'slash', 'levelLearnedAt': 39},
#    {'name': 'growth', 'levelLearnedAt': 48}],
#   'walk',
#   nan,
#   "['cut', 'flash']",
#   "['bide', 'dig', 'body-slam', 'rest', 'reflect', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'mega-drain', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'solar-beam', 'mimic']"],
#  [46,
#   'exeggcute',
#   [{'name': 'hypnosis', 'levelLearnedAt': 1},
#    {'name': 'barrage', 'levelLearnedAt': 1},
#    {'name': 'reflect', 'levelLearnedAt': 25},
#    {'name': 'leech-seed', 'levelLearnedAt': 28},
#    {'name': 'stun-spore', 'levelLearnedAt': 32},
#    {'name': 'poison-powder', 'levelLearnedAt': 37},
#    {'name': 'solar-beam', 'levelLearnedAt': 42},
#    {'name': 'sleep-powder', 'levelLearnedAt': 48}],
#   'walk',
#   nan,
#   "['flash', 'strength']",
#   "['bide', 'rest', 'teleport', 'reflect', 'double-edge', 'substitute', 'mega-drain', 'double-team', 'egg-bomb', 'dream-eater', 'rage', 'toxic', 'self-destruct', 'take-down', 'swords-dance', 'psywave', 'solar-beam', 'psychic', 'mimic', 'explosion']"],
#  [47,
#   'rhyhorn',
#   [{'name': 'horn-attack', 'levelLearnedAt': 1},
#    {'name': 'stomp', 'levelLearnedAt': 30},
#    {'name': 'tail-whip', 'levelLearnedAt': 35},
#    {'name': 'fury-attack', 'levelLearnedAt': 40},
#    {'name': 'horn-drill', 'levelLearnedAt': 45},
#    {'name': 'leer', 'levelLearnedAt': 50},
#    {'name': 'take-down', 'levelLearnedAt': 55}],
#   'walk',
#   nan,
#   "['strength']",
#   "['bide', 'thunder', 'dig', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'horn-drill', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'earthquake', 'blizzard', 'mimic', 'fire-blast', 'fissure']"],
#  [48,
#   'chansey',
#   [{'name': 'pound', 'levelLearnedAt': 1},
#    {'name': 'double-slap', 'levelLearnedAt': 1},
#    {'name': 'sing', 'levelLearnedAt': 24},
#    {'name': 'growl', 'levelLearnedAt': 30},
#    {'name': 'minimize', 'levelLearnedAt': 38},
#    {'name': 'defense-curl', 'levelLearnedAt': 44},
#    {'name': 'light-screen', 'levelLearnedAt': 48},
#    {'name': 'double-edge', 'levelLearnedAt': 54}],
#   'walk',
#   nan,
#   "['flash', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'thunder', 'thunder-wave', 'seismic-toss', 'thunderbolt', 'body-slam', 'rest', 'teleport', 'ice-beam', 'rock-slide', 'tri-attack', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'hyper-beam', 'soft-boiled', 'substitute', 'skull-bash', 'double-team', 'egg-bomb', 'dream-eater', 'rage', 'toxic', 'take-down', 'earthquake', 'psywave', 'blizzard', 'solar-beam', 'psychic', 'mimic', 'metronome', 'fire-blast']"],
#  [49,
#   'pinsir',
#   [{'name': 'vise-grip', 'levelLearnedAt': 1},
#    {'name': 'seismic-toss', 'levelLearnedAt': 25},
#    {'name': 'guillotine', 'levelLearnedAt': 30},
#    {'name': 'focus-energy', 'levelLearnedAt': 36},
#    {'name': 'harden', 'levelLearnedAt': 43},
#    {'name': 'slash', 'levelLearnedAt': 49},
#    {'name': 'swords-dance', 'levelLearnedAt': 54}],
#   'walk',
#   nan,
#   "['cut', 'strength']",
#   "['bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'rock-slide', 'submission', 'double-edge', 'hyper-beam', 'substitute', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'earthquake', 'mimic']"],
#  [50,
#   'dratini',
#   [{'name': 'wrap', 'levelLearnedAt': 1},
#    {'name': 'leer', 'levelLearnedAt': 1},
#    {'name': 'thunder-wave', 'levelLearnedAt': 10},
#    {'name': 'agility', 'levelLearnedAt': 20},
#    {'name': 'slam', 'levelLearnedAt': 30},
#    {'name': 'dragon-rage', 'levelLearnedAt': 40},
#    {'name': 'hyper-beam', 'levelLearnedAt': 50}],
#   'walk',
#   nan,
#   "['surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'thunder-wave', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'dragon-rage', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic', 'fire-blast']"],
#  [51,
#   'doduo',
#   [{'name': 'peck', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 20},
#    {'name': 'fury-attack', 'levelLearnedAt': 24},
#    {'name': 'drill-peck', 'levelLearnedAt': 30},
#    {'name': 'rage', 'levelLearnedAt': 36},
#    {'name': 'tri-attack', 'levelLearnedAt': 40},
#    {'name': 'agility', 'levelLearnedAt': 44}],
#   'walk',
#   nan,
#   "['fly']",
#   "['whirlwind', 'bide', 'body-slam', 'rest', 'tri-attack', 'reflect', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'swords-dance', 'mimic', 'sky-attack']"],
#  [52,
#   'kangaskhan',
#   [{'name': 'comet-punch', 'levelLearnedAt': 1},
#    {'name': 'rage', 'levelLearnedAt': 1},
#    {'name': 'bite', 'levelLearnedAt': 26},
#    {'name': 'tail-whip', 'levelLearnedAt': 31},
#    {'name': 'mega-punch', 'levelLearnedAt': 36},
#    {'name': 'leer', 'levelLearnedAt': 41},
#    {'name': 'dizzy-punch', 'levelLearnedAt': 46}],
#   'walk',
#   nan,
#   "['cut', 'surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'thunder', 'seismic-toss', 'dig', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'mega-kick', 'submission', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'earthquake', 'blizzard', 'solar-beam', 'mimic', 'fire-blast', 'fissure']"],
#  [53,
#   'venomoth',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'disable', 'levelLearnedAt': 1},
#    {'name': 'poison-powder', 'levelLearnedAt': 24},
#    {'name': 'leech-life', 'levelLearnedAt': 27},
#    {'name': 'stun-spore', 'levelLearnedAt': 30},
#    {'name': 'psybeam', 'levelLearnedAt': 38},
#    {'name': 'sleep-powder', 'levelLearnedAt': 43},
#    {'name': 'psychic', 'levelLearnedAt': 50}],
#   'walk',
#   nan,
#   "['flash']",
#   "['whirlwind', 'bide', 'rest', 'teleport', 'reflect', 'razor-wind', 'double-edge', 'hyper-beam', 'substitute', 'mega-drain', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'psywave', 'solar-beam', 'psychic', 'mimic']"],
#  [54,
#   'tauros',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'stomp', 'levelLearnedAt': 21},
#    {'name': 'tail-whip', 'levelLearnedAt': 28},
#    {'name': 'leer', 'levelLearnedAt': 35},
#    {'name': 'rage', 'levelLearnedAt': 44},
#    {'name': 'take-down', 'levelLearnedAt': 51}],
#   'walk',
#   nan,
#   "['surf', 'strength']",
#   "['bide', 'thunder', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'horn-drill', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'earthquake', 'blizzard', 'solar-beam', 'mimic', 'fire-blast', 'fissure']"],
#  [55,
#   'golbat',
#   [{'name': 'screech', 'levelLearnedAt': 1},
#    {'name': 'leech-life', 'levelLearnedAt': 1},
#    {'name': 'supersonic', 'levelLearnedAt': 10},
#    {'name': 'bite', 'levelLearnedAt': 15},
#    {'name': 'confuse-ray', 'levelLearnedAt': 21},
#    {'name': 'wing-attack', 'levelLearnedAt': 32},
#    {'name': 'haze', 'levelLearnedAt': 43}],
#   'walk',
#   nan,
#   "['fly']",
#   "['whirlwind', 'bide', 'rest', 'razor-wind', 'double-edge', 'hyper-beam', 'substitute', 'mega-drain', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic']"],
#  [56,
#   'slowbro',
#   [{'name': 'confusion', 'levelLearnedAt': 1},
#    {'name': 'disable', 'levelLearnedAt': 18},
#    {'name': 'headbutt', 'levelLearnedAt': 22},
#    {'name': 'growl', 'levelLearnedAt': 27},
#    {'name': 'water-gun', 'levelLearnedAt': 33},
#    {'name': 'withdraw', 'levelLearnedAt': 37},
#    {'name': 'amnesia', 'levelLearnedAt': 44},
#    {'name': 'psychic', 'levelLearnedAt': 55}],
#   'walk',
#   nan,
#   "['flash', 'surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'thunder-wave', 'seismic-toss', 'dig', 'body-slam', 'rest', 'teleport', 'ice-beam', 'tri-attack', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'swift', 'dream-eater', 'rage', 'toxic', 'take-down', 'earthquake', 'psywave', 'blizzard', 'psychic', 'mimic', 'fire-blast', 'fissure']"],
#  [57,
#   'seel',
#   [{'name': 'headbutt', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 30},
#    {'name': 'aurora-beam', 'levelLearnedAt': 35},
#    {'name': 'rest', 'levelLearnedAt': 40},
#    {'name': 'take-down', 'levelLearnedAt': 45},
#    {'name': 'ice-beam', 'levelLearnedAt': 50}],
#   'walk',
#   nan,
#   "['surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'bide', 'body-slam', 'rest', 'ice-beam', 'horn-drill', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [58,
#   'staryu',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'water-gun', 'levelLearnedAt': 17},
#    {'name': 'harden', 'levelLearnedAt': 22},
#    {'name': 'recover', 'levelLearnedAt': 27},
#    {'name': 'swift', 'levelLearnedAt': 32},
#    {'name': 'minimize', 'levelLearnedAt': 37},
#    {'name': 'light-screen', 'levelLearnedAt': 42},
#    {'name': 'hydro-pump', 'levelLearnedAt': 47}],
#   'walk',
#   nan,
#   "['flash', 'surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'thunder-wave', 'thunderbolt', 'rest', 'teleport', 'ice-beam', 'tri-attack', 'reflect', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'psywave', 'blizzard', 'psychic', 'mimic']"],
#  [59,
#   'dewgong',
#   [{'name': 'headbutt', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 30},
#    {'name': 'aurora-beam', 'levelLearnedAt': 35},
#    {'name': 'rest', 'levelLearnedAt': 44},
#    {'name': 'take-down', 'levelLearnedAt': 50},
#    {'name': 'ice-beam', 'levelLearnedAt': 56}],
#   'walk',
#   nan,
#   "['surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'bide', 'body-slam', 'rest', 'ice-beam', 'horn-drill', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [60,
#   'kingler',
#   [{'name': 'leer', 'levelLearnedAt': 1},
#    {'name': 'bubble', 'levelLearnedAt': 1},
#    {'name': 'vise-grip', 'levelLearnedAt': 20},
#    {'name': 'guillotine', 'levelLearnedAt': 25},
#    {'name': 'stomp', 'levelLearnedAt': 34},
#    {'name': 'crabhammer', 'levelLearnedAt': 42},
#    {'name': 'harden', 'levelLearnedAt': 49}],
#   'walk',
#   nan,
#   "['cut', 'surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'bide', 'dig', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'double-edge', 'hyper-beam', 'substitute', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'blizzard', 'mimic']"],
#  [61,
#   'golduck',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'tail-whip', 'levelLearnedAt': 28},
#    {'name': 'disable', 'levelLearnedAt': 31},
#    {'name': 'confusion', 'levelLearnedAt': 39},
#    {'name': 'fury-swipes', 'levelLearnedAt': 48},
#    {'name': 'hydro-pump', 'levelLearnedAt': 59}],
#   'walk',
#   nan,
#   "['flash', 'surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'ice-beam', 'mega-kick', 'submission', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'psychic', 'mimic']"],
#  [62,
#   'horsea',
#   [{'name': 'bubble', 'levelLearnedAt': 1},
#    {'name': 'smokescreen', 'levelLearnedAt': 19},
#    {'name': 'leer', 'levelLearnedAt': 24},
#    {'name': 'water-gun', 'levelLearnedAt': 30},
#    {'name': 'agility', 'levelLearnedAt': 37},
#    {'name': 'hydro-pump', 'levelLearnedAt': 45}],
#   'fishing',
#   nan,
#   "['surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'rest', 'ice-beam', 'razor-wind', 'double-edge', 'substitute', 'dragon-rage', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [63,
#   'articuno',
#   [{'name': 'ice-beam', 'levelLearnedAt': 1},
#    {'name': 'peck', 'levelLearnedAt': 1},
#    {'name': 'blizzard', 'levelLearnedAt': 51},
#    {'name': 'agility', 'levelLearnedAt': 55},
#    {'name': 'mist', 'levelLearnedAt': 60}],
#   'walk',
#   nan,
#   "['fly']",
#   "['bubble-beam', 'whirlwind', 'water-gun', 'bide', 'rest', 'ice-beam', 'reflect', 'razor-wind', 'double-edge', 'hyper-beam', 'substitute', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic', 'sky-attack']"],
#  [64,
#   'raticate',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'tail-whip', 'levelLearnedAt': 1},
#    {'name': 'quick-attack', 'levelLearnedAt': 7},
#    {'name': 'hyper-fang', 'levelLearnedAt': 14},
#    {'name': 'focus-energy', 'levelLearnedAt': 27},
#    {'name': 'super-fang', 'levelLearnedAt': 41}],
#   'walk',
#   nan,
#   "['cut', 'strength']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'thunder-wave', 'dig', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'swords-dance', 'blizzard', 'mimic']"],
#  [65,
#   'tangela',
#   [{'name': 'bind', 'levelLearnedAt': 1},
#    {'name': 'constrict', 'levelLearnedAt': 1},
#    {'name': 'absorb', 'levelLearnedAt': 29},
#    {'name': 'poison-powder', 'levelLearnedAt': 32},
#    {'name': 'stun-spore', 'levelLearnedAt': 36},
#    {'name': 'sleep-powder', 'levelLearnedAt': 39},
#    {'name': 'slam', 'levelLearnedAt': 45},
#    {'name': 'growth', 'levelLearnedAt': 49}],
#   'walk',
#   nan,
#   "['cut', 'flash']",
#   "['bide', 'body-slam', 'rest', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'mega-drain', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'solar-beam', 'mimic']"],
#  [66,
#   'raichu',
#   [{'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'thunder-shock', 'levelLearnedAt': 1},
#    {'name': 'thunder-wave', 'levelLearnedAt': 1}],
#   'walk',
#   nan,
#   "['flash', 'strength']",
#   "['mega-punch', 'bide', 'thunder', 'thunder-wave', 'seismic-toss', 'dig', 'thunderbolt', 'body-slam', 'rest', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'swift', 'rage', 'toxic', 'take-down', 'mimic']"],
#  [67,
#   'magnemite',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'sonic-boom', 'levelLearnedAt': 21},
#    {'name': 'thunder-shock', 'levelLearnedAt': 25},
#    {'name': 'supersonic', 'levelLearnedAt': 29},
#    {'name': 'thunder-wave', 'levelLearnedAt': 35},
#    {'name': 'swift', 'levelLearnedAt': 41},
#    {'name': 'screech', 'levelLearnedAt': 47}],
#   'walk',
#   nan,
#   "['flash']",
#   "['bide', 'thunder', 'thunder-wave', 'thunderbolt', 'rest', 'teleport', 'reflect', 'double-edge', 'substitute', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic', 'explosion']"],
#  [68,
#   'magneton',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'sonic-boom', 'levelLearnedAt': 21},
#    {'name': 'thunder-shock', 'levelLearnedAt': 25},
#    {'name': 'supersonic', 'levelLearnedAt': 29},
#    {'name': 'thunder-wave', 'levelLearnedAt': 38},
#    {'name': 'swift', 'levelLearnedAt': 46},
#    {'name': 'screech', 'levelLearnedAt': 54}],
#   'walk',
#   nan,
#   "['flash']",
#   "['bide', 'thunder', 'thunder-wave', 'thunderbolt', 'rest', 'teleport', 'tri-attack', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic', 'explosion']"],
#  [69,
#   'electrode',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'screech', 'levelLearnedAt': 1},
#    {'name': 'sonic-boom', 'levelLearnedAt': 17},
#    {'name': 'self-destruct', 'levelLearnedAt': 22},
#    {'name': 'light-screen', 'levelLearnedAt': 29},
#    {'name': 'swift', 'levelLearnedAt': 40},
#    {'name': 'explosion', 'levelLearnedAt': 50}],
#   'walk',
#   nan,
#   "['flash']",
#   "['bide', 'thunder', 'thunder-wave', 'thunderbolt', 'rest', 'teleport', 'reflect', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'self-destruct', 'take-down', 'mimic', 'explosion']"],
#  [70,
#   'zapdos',
#   [{'name': 'drill-peck', 'levelLearnedAt': 1},
#    {'name': 'thunder-shock', 'levelLearnedAt': 1},
#    {'name': 'thunder', 'levelLearnedAt': 51},
#    {'name': 'agility', 'levelLearnedAt': 55},
#    {'name': 'light-screen', 'levelLearnedAt': 60}],
#   'walk',
#   nan,
#   "['flash', 'fly']",
#   "['whirlwind', 'bide', 'thunder', 'thunder-wave', 'thunderbolt', 'rest', 'reflect', 'razor-wind', 'double-edge', 'hyper-beam', 'substitute', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic', 'sky-attack']"],
#  [71,
#   'fearow',
#   [{'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'peck', 'levelLearnedAt': 1},
#    {'name': 'leer', 'levelLearnedAt': 9},
#    {'name': 'fury-attack', 'levelLearnedAt': 15},
#    {'name': 'mirror-move', 'levelLearnedAt': 25},
#    {'name': 'drill-peck', 'levelLearnedAt': 34},
#    {'name': 'agility', 'levelLearnedAt': 43}],
#   'walk',
#   nan,
#   "['fly']",
#   "['whirlwind', 'bide', 'rest', 'razor-wind', 'double-edge', 'hyper-beam', 'substitute', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic', 'sky-attack']"],
#  [72,
#   'ponyta',
#   [{'name': 'ember', 'levelLearnedAt': 1},
#    {'name': 'tail-whip', 'levelLearnedAt': 30},
#    {'name': 'stomp', 'levelLearnedAt': 32},
#    {'name': 'growl', 'levelLearnedAt': 35},
#    {'name': 'fire-spin', 'levelLearnedAt': 39},
#    {'name': 'take-down', 'levelLearnedAt': 43},
#    {'name': 'agility', 'levelLearnedAt': 48}],
#   'walk',
#   nan,
#   "['strength']",
#   "['bide', 'body-slam', 'rest', 'reflect', 'horn-drill', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'solar-beam', 'mimic', 'fire-blast']"],
#  [73,
#   'grimer',
#   [{'name': 'pound', 'levelLearnedAt': 1},
#    {'name': 'disable', 'levelLearnedAt': 1},
#    {'name': 'poison-gas', 'levelLearnedAt': 30},
#    {'name': 'minimize', 'levelLearnedAt': 33},
#    {'name': 'sludge', 'levelLearnedAt': 37},
#    {'name': 'harden', 'levelLearnedAt': 42},
#    {'name': 'screech', 'levelLearnedAt': 48},
#    {'name': 'acid-armor', 'levelLearnedAt': 55}],
#   'walk',
#   nan,
#   "['strength']",
#   "['bide', 'thunder', 'dig', 'thunderbolt', 'body-slam', 'rest', 'rock-slide', 'substitute', 'mega-drain', 'double-team', 'rage', 'toxic', 'self-destruct', 'mimic', 'fire-blast', 'explosion']"],
#  [74,
#   'muk',
#   [{'name': 'pound', 'levelLearnedAt': 1},
#    {'name': 'disable', 'levelLearnedAt': 1},
#    {'name': 'poison-gas', 'levelLearnedAt': 30},
#    {'name': 'minimize', 'levelLearnedAt': 33},
#    {'name': 'sludge', 'levelLearnedAt': 37},
#    {'name': 'harden', 'levelLearnedAt': 45},
#    {'name': 'screech', 'levelLearnedAt': 53},
#    {'name': 'acid-armor', 'levelLearnedAt': 60}],
#   'walk',
#   nan,
#   "['strength']",
#   "['bide', 'thunder', 'dig', 'thunderbolt', 'body-slam', 'rest', 'rock-slide', 'hyper-beam', 'substitute', 'mega-drain', 'double-team', 'rage', 'toxic', 'self-destruct', 'mimic', 'fire-blast', 'explosion']"],
#  [75,
#   'koffing',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'smog', 'levelLearnedAt': 1},
#    {'name': 'sludge', 'levelLearnedAt': 32},
#    {'name': 'smokescreen', 'levelLearnedAt': 37},
#    {'name': 'self-destruct', 'levelLearnedAt': 40},
#    {'name': 'haze', 'levelLearnedAt': 45},
#    {'name': 'explosion', 'levelLearnedAt': 48}],
#   'walk',
#   nan,
#   "['flash']",
#   "['bide', 'thunder', 'thunderbolt', 'rest', 'substitute', 'double-team', 'rage', 'toxic', 'self-destruct', 'psywave', 'mimic', 'fire-blast', 'explosion']"],
#  [76,
#   'weezing',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'smog', 'levelLearnedAt': 1},
#    {'name': 'sludge', 'levelLearnedAt': 32},
#    {'name': 'smokescreen', 'levelLearnedAt': 39},
#    {'name': 'self-destruct', 'levelLearnedAt': 43},
#    {'name': 'haze', 'levelLearnedAt': 49},
#    {'name': 'explosion', 'levelLearnedAt': 53}],
#   'walk',
#   nan,
#   "['flash']",
#   "['bide', 'thunder', 'thunderbolt', 'rest', 'hyper-beam', 'substitute', 'double-team', 'rage', 'toxic', 'self-destruct', 'mimic', 'fire-blast', 'explosion']"],
#  [77,
#   'magmar',
#   [{'name': 'ember', 'levelLearnedAt': 1},
#    {'name': 'leer', 'levelLearnedAt': 36},
#    {'name': 'confuse-ray', 'levelLearnedAt': 39},
#    {'name': 'fire-punch', 'levelLearnedAt': 43},
#    {'name': 'smokescreen', 'levelLearnedAt': 48},
#    {'name': 'smog', 'levelLearnedAt': 52},
#    {'name': 'flamethrower', 'levelLearnedAt': 55}],
#   'walk',
#   nan,
#   "['strength']",
#   "['mega-punch', 'bide', 'seismic-toss', 'body-slam', 'rest', 'teleport', 'mega-kick', 'submission', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'psywave', 'psychic', 'mimic', 'metronome', 'fire-blast']"],
#  [78,
#   'sandslash',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'sand-attack', 'levelLearnedAt': 10},
#    {'name': 'slash', 'levelLearnedAt': 17},
#    {'name': 'poison-sting', 'levelLearnedAt': 27},
#    {'name': 'swift', 'levelLearnedAt': 36},
#    {'name': 'fury-swipes', 'levelLearnedAt': 47}],
#   'walk',
#   nan,
#   "['cut', 'strength']",
#   "['bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'rock-slide', 'submission', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'swords-dance', 'earthquake', 'mimic', 'fissure']"],
#  [79,
#   'seadra',
#   [{'name': 'bubble', 'levelLearnedAt': 1},
#    {'name': 'smokescreen', 'levelLearnedAt': 19},
#    {'name': 'leer', 'levelLearnedAt': 24},
#    {'name': 'water-gun', 'levelLearnedAt': 30},
#    {'name': 'agility', 'levelLearnedAt': 41},
#    {'name': 'hydro-pump', 'levelLearnedAt': 52}],
#   'walk',
#   nan,
#   "['surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'rest', 'ice-beam', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [80,
#   'seaking',
#   [{'name': 'tail-whip', 'levelLearnedAt': 1},
#    {'name': 'peck', 'levelLearnedAt': 1},
#    {'name': 'supersonic', 'levelLearnedAt': 19},
#    {'name': 'horn-attack', 'levelLearnedAt': 24},
#    {'name': 'fury-attack', 'levelLearnedAt': 30},
#    {'name': 'waterfall', 'levelLearnedAt': 39},
#    {'name': 'horn-drill', 'levelLearnedAt': 48},
#    {'name': 'agility', 'levelLearnedAt': 54}],
#   'walk',
#   nan,
#   "['surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'rest', 'ice-beam', 'horn-drill', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [81,
#   'machoke',
#   [{'name': 'karate-chop', 'levelLearnedAt': 1},
#    {'name': 'low-kick', 'levelLearnedAt': 20},
#    {'name': 'leer', 'levelLearnedAt': 25},
#    {'name': 'focus-energy', 'levelLearnedAt': 36},
#    {'name': 'seismic-toss', 'levelLearnedAt': 44},
#    {'name': 'submission', 'levelLearnedAt': 52}],
#   'walk',
#   nan,
#   "['strength']",
#   "['mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'rock-slide', 'mega-kick', 'submission', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'earthquake', 'mimic', 'metronome', 'fire-blast', 'fissure']"],
#  [82,
#   'graveler',
# ...
#    {'name': 'disable', 'levelLearnedAt': 12},
#    {'name': 'confusion', 'levelLearnedAt': 17},
#    {'name': 'headbutt', 'levelLearnedAt': 24},
#    {'name': 'poison-gas', 'levelLearnedAt': 33},
#    {'name': 'psychic', 'levelLearnedAt': 37},
#    {'name': 'meditate', 'levelLearnedAt': 43}],
#   '26',
#   'walk',
#   "['flash']",
#   "['mega-punch', 'bide', 'thunder-wave', 'seismic-toss', 'body-slam', 'rest', 'teleport', 'tri-attack', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'dream-eater', 'rage', 'toxic', 'take-down', 'psywave', 'psychic', 'mimic', 'metronome']"],
#  [112,
#   'persian',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'bite', 'levelLearnedAt': 12},
#    {'name': 'pay-day', 'levelLearnedAt': 17},
#    {'name': 'screech', 'levelLearnedAt': 24},
#    {'name': 'fury-swipes', 'levelLearnedAt': 37},
#    {'name': 'slash', 'levelLearnedAt': 51}],
#   '28',
#   'walk',
#   "['cut', 'flash']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'dig', 'thunderbolt', 'body-slam', 'rest', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'swift', 'dream-eater', 'rage', 'toxic', 'take-down', 'mimic']"],
#  [113,
#   'machamp',
#   [{'name': 'karate-chop', 'levelLearnedAt': 1},
#    {'name': 'low-kick', 'levelLearnedAt': 20},
#    {'name': 'leer', 'levelLearnedAt': 25},
#    {'name': 'focus-energy', 'levelLearnedAt': 36},
#    {'name': 'seismic-toss', 'levelLearnedAt': 44},
#    {'name': 'submission', 'levelLearnedAt': 52}],
#   'trade',
#   'walk',
#   "['strength']",
#   "['mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'rock-slide', 'mega-kick', 'submission', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'earthquake', 'mimic', 'metronome', 'fire-blast', 'fissure']"],
#  [114,
#   'ninetales',
#   [{'name': 'tail-whip', 'levelLearnedAt': 1},
#    {'name': 'roar', 'levelLearnedAt': 1},
#    {'name': 'ember', 'levelLearnedAt': 1},
#    {'name': 'quick-attack', 'levelLearnedAt': 1}],
#   'fire-stone',
#   'walk',
#   '[]',
#   "['bide', 'dig', 'body-slam', 'rest', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'dream-eater', 'rage', 'toxic', 'take-down', 'solar-beam', 'mimic', 'fire-blast']"],
#  [115,
#   'gengar',
#   [{'name': 'night-shade', 'levelLearnedAt': 1},
#    {'name': 'confuse-ray', 'levelLearnedAt': 1},
#    {'name': 'lick', 'levelLearnedAt': 1},
#    {'name': 'hypnosis', 'levelLearnedAt': 29},
#    {'name': 'dream-eater', 'levelLearnedAt': 38}],
#   'trade',
#   'walk',
#   "['strength']",
#   "['mega-punch', 'bide', 'thunder', 'seismic-toss', 'thunderbolt', 'body-slam', 'rest', 'mega-kick', 'submission', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'mega-drain', 'skull-bash', 'double-team', 'dream-eater', 'rage', 'toxic', 'self-destruct', 'take-down', 'psywave', 'psychic', 'mimic', 'metronome', 'explosion']"],
#  [116,
#   'tentacruel',
#   [{'name': 'acid', 'levelLearnedAt': 1},
#    {'name': 'supersonic', 'levelLearnedAt': 7},
#    {'name': 'wrap', 'levelLearnedAt': 13},
#    {'name': 'poison-sting', 'levelLearnedAt': 18},
#    {'name': 'water-gun', 'levelLearnedAt': 22},
#    {'name': 'constrict', 'levelLearnedAt': 27},
#    {'name': 'barrier', 'levelLearnedAt': 35},
#    {'name': 'screech', 'levelLearnedAt': 43},
#    {'name': 'hydro-pump', 'levelLearnedAt': 50}],
#   '30',
#   'fishing',
#   "['cut', 'surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'rest', 'ice-beam', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'mega-drain', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'blizzard', 'mimic']"],
#  [117,
#   'exeggutor',
#   [{'name': 'hypnosis', 'levelLearnedAt': 1},
#    {'name': 'barrage', 'levelLearnedAt': 1},
#    {'name': 'stomp', 'levelLearnedAt': 28}],
#   'leaf-stone',
#   'walk',
#   "['flash', 'strength']",
#   "['bide', 'rest', 'teleport', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'mega-drain', 'double-team', 'egg-bomb', 'dream-eater', 'rage', 'toxic', 'self-destruct', 'take-down', 'swords-dance', 'psywave', 'solar-beam', 'psychic', 'mimic', 'explosion']"],
#  [118,
#   'rhydon',
#   [{'name': 'horn-attack', 'levelLearnedAt': 1},
#    {'name': 'stomp', 'levelLearnedAt': 30},
#    {'name': 'tail-whip', 'levelLearnedAt': 35},
#    {'name': 'fury-attack', 'levelLearnedAt': 40},
#    {'name': 'horn-drill', 'levelLearnedAt': 48},
#    {'name': 'leer', 'levelLearnedAt': 55},
#    {'name': 'take-down', 'levelLearnedAt': 64}],
#   '42',
#   'walk',
#   "['cut', 'surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'thunder', 'seismic-toss', 'dig', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'mega-kick', 'submission', 'horn-drill', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'pay-day', 'rage', 'toxic', 'take-down', 'swords-dance', 'earthquake', 'blizzard', 'mimic', 'fire-blast', 'fissure']"],
#  [119,
#   'dragonair',
#   [{'name': 'wrap', 'levelLearnedAt': 1},
#    {'name': 'leer', 'levelLearnedAt': 1},
#    {'name': 'thunder-wave', 'levelLearnedAt': 10},
#    {'name': 'agility', 'levelLearnedAt': 20},
#    {'name': 'slam', 'levelLearnedAt': 35},
#    {'name': 'dragon-rage', 'levelLearnedAt': 45},
#    {'name': 'hyper-beam', 'levelLearnedAt': 55}],
#   '30',
#   'walk',
#   "['surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'thunder-wave', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'reflect', 'horn-drill', 'double-edge', 'hyper-beam', 'substitute', 'dragon-rage', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic', 'fire-blast']"],
#  [120,
#   'dragonite',
#   [{'name': 'wrap', 'levelLearnedAt': 1},
#    {'name': 'leer', 'levelLearnedAt': 1},
#    {'name': 'thunder-wave', 'levelLearnedAt': 10},
#    {'name': 'agility', 'levelLearnedAt': 20},
#    {'name': 'slam', 'levelLearnedAt': 35},
#    {'name': 'dragon-rage', 'levelLearnedAt': 45},
#    {'name': 'hyper-beam', 'levelLearnedAt': 60}],
#   '55',
#   'walk',
#   "['cut', 'fly', 'surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'thunder-wave', 'thunderbolt', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'reflect', 'razor-wind', 'horn-drill', 'double-edge', 'hyper-beam', 'substitute', 'dragon-rage', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'earthquake', 'blizzard', 'mimic', 'fire-blast']"],
#  [121,
#   'dodrio',
#   [{'name': 'peck', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 20},
#    {'name': 'fury-attack', 'levelLearnedAt': 24},
#    {'name': 'drill-peck', 'levelLearnedAt': 30},
#    {'name': 'rage', 'levelLearnedAt': 39},
#    {'name': 'tri-attack', 'levelLearnedAt': 45},
#    {'name': 'agility', 'levelLearnedAt': 51}],
#   '31',
#   'walk',
#   "['fly']",
#   "['whirlwind', 'bide', 'body-slam', 'rest', 'tri-attack', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'swords-dance', 'mimic', 'sky-attack']"],
#  [122,
#   'starmie',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'water-gun', 'levelLearnedAt': 1},
#    {'name': 'harden', 'levelLearnedAt': 1}],
#   'water-stone',
#   'walk',
#   "['flash', 'surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'thunder', 'thunder-wave', 'thunderbolt', 'rest', 'teleport', 'ice-beam', 'tri-attack', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'dream-eater', 'rage', 'toxic', 'take-down', 'psywave', 'blizzard', 'psychic', 'mimic']"],
#  [123,
#   'rapidash',
#   [{'name': 'ember', 'levelLearnedAt': 1},
#    {'name': 'tail-whip', 'levelLearnedAt': 30},
#    {'name': 'stomp', 'levelLearnedAt': 32},
#    {'name': 'growl', 'levelLearnedAt': 35},
#    {'name': 'fire-spin', 'levelLearnedAt': 39},
#    {'name': 'take-down', 'levelLearnedAt': 47},
#    {'name': 'agility', 'levelLearnedAt': 55}],
#   '40',
#   'walk',
#   "['strength']",
#   "['bide', 'body-slam', 'rest', 'reflect', 'horn-drill', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'solar-beam', 'mimic', 'fire-blast']"],
#  [124,
#   'ivysaur',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'leech-seed', 'levelLearnedAt': 7},
#    {'name': 'vine-whip', 'levelLearnedAt': 13},
#    {'name': 'poison-powder', 'levelLearnedAt': 22},
#    {'name': 'razor-leaf', 'levelLearnedAt': 30},
#    {'name': 'growth', 'levelLearnedAt': 38},
#    {'name': 'sleep-powder', 'levelLearnedAt': 46},
#    {'name': 'solar-beam', 'levelLearnedAt': 54}],
#   '16',
#   'starter',
#   "['cut', 'flash', 'strength']",
#   "['bide', 'body-slam', 'rest', 'reflect', 'double-edge', 'substitute', 'mega-drain', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'solar-beam', 'mimic']"],
#  [125,
#   'venusaur',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'leech-seed', 'levelLearnedAt': 7},
#    {'name': 'vine-whip', 'levelLearnedAt': 13},
#    {'name': 'poison-powder', 'levelLearnedAt': 22},
#    {'name': 'razor-leaf', 'levelLearnedAt': 30},
#    {'name': 'growth', 'levelLearnedAt': 43},
#    {'name': 'sleep-powder', 'levelLearnedAt': 55},
#    {'name': 'solar-beam', 'levelLearnedAt': 65}],
#   '32',
#   'starter',
#   "['cut', 'flash', 'strength']",
#   "['bide', 'body-slam', 'rest', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'mega-drain', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'earthquake', 'solar-beam', 'mimic']"],
#  [126,
#   'charmeleon',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'ember', 'levelLearnedAt': 9},
#    {'name': 'leer', 'levelLearnedAt': 15},
#    {'name': 'rage', 'levelLearnedAt': 24},
#    {'name': 'slash', 'levelLearnedAt': 33},
#    {'name': 'flamethrower', 'levelLearnedAt': 42},
#    {'name': 'fire-spin', 'levelLearnedAt': 56}],
#   '16',
#   'starter',
#   "['cut', 'strength']",
#   "['mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'rock-slide', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'substitute', 'dragon-rage', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'swords-dance', 'mimic', 'fire-blast']"],
#  [127,
#   'charizard',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'growl', 'levelLearnedAt': 1},
#    {'name': 'ember', 'levelLearnedAt': 9},
#    {'name': 'leer', 'levelLearnedAt': 15},
#    {'name': 'rage', 'levelLearnedAt': 24},
#    {'name': 'slash', 'levelLearnedAt': 36},
#    {'name': 'flamethrower', 'levelLearnedAt': 46},
#    {'name': 'fire-spin', 'levelLearnedAt': 55}],
#   '36',
#   'starter',
#   "['cut', 'fly', 'strength']",
#   "['mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'rock-slide', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'dragon-rage', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'swords-dance', 'earthquake', 'solar-beam', 'mimic', 'fire-blast', 'fissure']"],
#  [128,
#   'wartortle',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'tail-whip', 'levelLearnedAt': 1},
#    {'name': 'bubble', 'levelLearnedAt': 8},
#    {'name': 'water-gun', 'levelLearnedAt': 15},
#    {'name': 'bite', 'levelLearnedAt': 24},
#    {'name': 'withdraw', 'levelLearnedAt': 31},
#    {'name': 'skull-bash', 'levelLearnedAt': 39},
#    {'name': 'hydro-pump', 'levelLearnedAt': 47}],
#   '16',
#   'starter',
#   "['surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'ice-beam', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [129,
#   'blastoise',
#   [{'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'tail-whip', 'levelLearnedAt': 1},
#    {'name': 'bubble', 'levelLearnedAt': 8},
#    {'name': 'water-gun', 'levelLearnedAt': 15},
#    {'name': 'bite', 'levelLearnedAt': 24},
#    {'name': 'withdraw', 'levelLearnedAt': 31},
#    {'name': 'skull-bash', 'levelLearnedAt': 42},
#    {'name': 'hydro-pump', 'levelLearnedAt': 52}],
#   '36',
#   'starter',
#   "['surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'mega-punch', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'mega-kick', 'submission', 'reflect', 'counter', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'earthquake', 'blizzard', 'mimic', 'fissure']"],
#  [130,
#   'kabutops',
#   [{'name': 'scratch', 'levelLearnedAt': 1},
#    {'name': 'harden', 'levelLearnedAt': 1},
#    {'name': 'absorb', 'levelLearnedAt': 34},
#    {'name': 'slash', 'levelLearnedAt': 39},
#    {'name': 'leer', 'levelLearnedAt': 46},
#    {'name': 'hydro-pump', 'levelLearnedAt': 53}],
#   '40',
#   'special',
#   "['cut', 'surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'seismic-toss', 'dig', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'mega-kick', 'submission', 'reflect', 'razor-wind', 'double-edge', 'hyper-beam', 'substitute', 'mega-drain', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'swords-dance', 'blizzard', 'mimic']"],
#  [131,
#   'omastar',
#   [{'name': 'water-gun', 'levelLearnedAt': 1},
#    {'name': 'withdraw', 'levelLearnedAt': 1},
#    {'name': 'horn-attack', 'levelLearnedAt': 34},
#    {'name': 'leer', 'levelLearnedAt': 39},
#    {'name': 'spike-cannon', 'levelLearnedAt': 44},
#    {'name': 'hydro-pump', 'levelLearnedAt': 49}],
#   '40',
#   'special',
#   "['surf']",
#   "['bubble-beam', 'water-gun', 'bide', 'seismic-toss', 'body-slam', 'rest', 'ice-beam', 'rock-slide', 'submission', 'reflect', 'horn-drill', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [132,
#   'vaporeon',
#   [{'name': 'sand-attack', 'levelLearnedAt': 1},
#    {'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'quick-attack', 'levelLearnedAt': 27},
#    {'name': 'water-gun', 'levelLearnedAt': 31},
#    {'name': 'tail-whip', 'levelLearnedAt': 37},
#    {'name': 'bite', 'levelLearnedAt': 40},
#    {'name': 'acid-armor', 'levelLearnedAt': 42},
#    {'name': 'haze', 'levelLearnedAt': 44},
#    {'name': 'mist', 'levelLearnedAt': 48},
#    {'name': 'hydro-pump', 'levelLearnedAt': 54}],
#   'water-stone',
#   'special',
#   "['surf', 'strength']",
#   "['bubble-beam', 'water-gun', 'bide', 'dig', 'body-slam', 'rest', 'ice-beam', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'blizzard', 'mimic']"],
#  [133,
#   'jolteon',
#   [{'name': 'sand-attack', 'levelLearnedAt': 1},
#    {'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'quick-attack', 'levelLearnedAt': 27},
#    {'name': 'thunder-shock', 'levelLearnedAt': 31},
#    {'name': 'tail-whip', 'levelLearnedAt': 37},
#    {'name': 'thunder-wave', 'levelLearnedAt': 40},
#    {'name': 'double-kick', 'levelLearnedAt': 42},
#    {'name': 'agility', 'levelLearnedAt': 44},
#    {'name': 'pin-missile', 'levelLearnedAt': 48},
#    {'name': 'thunder', 'levelLearnedAt': 54}],
#   'thunder-stone',
#   'special',
#   "['flash', 'strength']",
#   "['bide', 'thunder', 'thunder-wave', 'dig', 'thunderbolt', 'body-slam', 'rest', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic']"],
#  [134,
#   'flareon',
#   [{'name': 'sand-attack', 'levelLearnedAt': 1},
#    {'name': 'tackle', 'levelLearnedAt': 1},
#    {'name': 'quick-attack', 'levelLearnedAt': 27},
#    {'name': 'ember', 'levelLearnedAt': 31},
#    {'name': 'tail-whip', 'levelLearnedAt': 37},
#    {'name': 'bite', 'levelLearnedAt': 40},
#    {'name': 'leer', 'levelLearnedAt': 42},
#    {'name': 'fire-spin', 'levelLearnedAt': 44},
#    {'name': 'rage', 'levelLearnedAt': 48},
#    {'name': 'flamethrower', 'levelLearnedAt': 54}],
#   'fire-stone',
#   'special',
#   "['strength']",
#   "['bide', 'dig', 'body-slam', 'rest', 'reflect', 'double-edge', 'hyper-beam', 'substitute', 'skull-bash', 'double-team', 'swift', 'rage', 'toxic', 'take-down', 'mimic', 'fire-blast']"]]

# %%
import pandas as pd
import numpy as np
import json


# Diese func. sucht nach einem  moeglichen Team fuer die erste Arena
#
# @para1: encounterable_pokemon - liste von antreffbaren pokemon :: [index,name,encounterOrEvolutionTrigger,...]
# @para2: averageLevel - averageLevel des ArenaLeiters
# @para3: stones_available - Die Entw. Steine welche zur verfuegung stehen
# @return: poss_team_member - liste von pokemon welche mit dem averageLevel und den vorhanden Steinen erreichbar sind :: [index,name,encounterOrEvolutionTrigger,...]
def possPokemonArenaNLeaderM(encounterable_pokemon, averageLevel, stones_available):
    
    encounterable_pokemon_available = []
    
    for pokemon in encounterable_pokemon:
        encounterOrEvolutionTrigger = pokemon[3]
        if encounterOrEvolutionTrigger.isnumeric() and int(encounterOrEvolutionTrigger) <= averageLevel:
            encounterable_pokemon_available.append(pokemon)
        elif encounterOrEvolutionTrigger == 'walk' or encounterOrEvolutionTrigger == 'starter' or encounterOrEvolutionTrigger == 'special' or encounterOrEvolutionTrigger == 'trade':
            encounterable_pokemon_available.append(pokemon)
        elif encounterOrEvolutionTrigger in stones_available:
            encounterable_pokemon_available.append(pokemon)
    return encounterable_pokemon_available

# %%
x = possPokemonArenaNLeaderM(encounterable_pokemonParsed, 100, ["water-stone"] )
for p in x:
    print(p[3])
# Out:
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# walk
# starter
# starter
# starter
# special
# special
# special
# special
# special
# special
# special
# special
# special
# 36
# 10
# 10
# water-stone
# 20
# trade
# 16
# trade
# water-stone
# 26
# 28
# trade
# trade
# 30
# 42
# 30
# 55
# 31
# water-stone
# 40
# 16
# 32
# 16
# 36
# 16
# 36
# 40
# 40
# water-stone

# %%
# Diese func. gibt eine list von Moves, von encounter_pokemon zurueck.
# @para1: poss_team_member - DataFrame von moeglichen Team-Membern
# @para2: name - name des Pokemon. Dieser wird benoetigt um seine moves zu suchen.
# @para3: lock - ist ein schloss fuer das anfuegen der Moves an einer liste 
# @return: move_list - gibt eine liste der moeglichen moves zurueck.

def getPokemonMoves(poke_team, name, lock):
    # list der moves eines Pokemon
    move_list = []

    poke = poke_team.loc[poke_team["name"] == name, ["moves"]]
    poke = poke.values[0][0]
    poke = poke.replace("'", "\"") 
    poke = json.loads(poke)
    
    # Die Tabellen EncounterablePokemon und LeaderPokemon speichern die Moves
    # unterschiedlich. Bei der EncounterablePokemon ist in der Spalte 'Moves' ein
    # weiters DataFrame enthalten, wo die moves der Pokemon unter dem Value 'name'
    # gespeichert sind. Deshalb muessen das auslesen dafuer etwas anders gemacht werden
    # Wenn lock == 0 ist werden die Moves unsers Teams der List hinzugefuegt 
    # Wenn lock == 1 ist werden die Moves des Arena-Teams der list hinzugefuegt
    if lock == 0:
        for move in poke:
            move_list.append(move["name"])

    elif lock == 1:

        for move in poke:
            move_list.append(move)
            
    return move_list

# %%
def loadArena():
    
    return  [
             "arena-1",
             "arena-2",
             "arena-3",
             "arena-4",
             "arena-5",
             "arena-6",
             "arena-7",
             "arena-8",
             "arena-9",
             ]


# TODO: Anpassung der Pokemon lvl, die func. muss noch hinzugefuegt werden
#       AGV Pokemon Leader:
#       Arena 1: 13, Arena 2: 19.5, Arena 3: 21, Arena 4: 27.3, Arena 5: 39,
#       Arena 6: 39, Arena 7: 42.75, Arena 8: 45.2, Arena 9: 58.42
#
# TODO: Arena-9 fragen was blue spalten bedeuten
def loadOption(arena):
    #[
    #                  "moon-stone",
    #                  "fire-stone",
    #                  "thunder-stone",
    #                  "water-stone",
    #                  "leaf-stone",
    #                  ]

    list_of_stones = []
    
    arena1_stones = []
    arena2_stones =  arena1_stones + ["moon-stone"]
    arena3_stones = arena2_stones + []
    #... arena 4 - 9

    # Starter befor arena 1
    # Walk befor arean 1
    #
    # Moon after arena 2
    # Other stones arena 3
    #
    # Fishing 1 after arena 2
    # Fishing 2 after arena 3
    # Fishing 3 after arena 3

    if arena == "arena-1":
        pass
    elif arena == "arena-2":
        for stone in arena2_stones:  
            list_of_stones.append(stone)
    elif arena == "arena-3":
        for stone in arena3_stones:
            list_of_stones.append(stone)
    return list_of_stones
