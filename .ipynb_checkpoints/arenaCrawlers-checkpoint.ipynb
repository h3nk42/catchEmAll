# %%
# %run ./ArenaToCSV.ipynb

# %%
placeholderSteps = 0
# ---- GAME SETTINGS ---- #
STARTERS = ['bulbasaur','charmander','squirtle']
GENERATION = 'red-blue'
GAMES=['red','blue']
# ----  ---- #

# %%
# ---- ARENA-1 ---- #
POSSIBLE_TM_ARENA1 = []
POSSIBLE_VM_ARENA1 = []
# ---- ARENA SETTINGS ---- #
ARENA = 'arena-1'
LOCATIONS_ARENA1 =  [{'name':'kanto-route-1', 'steps':31},
              {'name':'kanto-route-2', 'steps':0},
              {'name':'viridian-forest', 'steps':110},
              {'name':'kanto-route-22', 'steps':placeholderSteps}]
SPECIALPOKEMON_ARENA1 = []
#leader
_geodude = {'name': 'geodude', 'level': 12, 'moves':['tackle','defense-curl']}
_onix = {'name': 'onix', 'level': 14, 'moves':['tackle','screech','bide','bind']}
LEADER = ('brock', [_geodude,_onix])
LEADERS=[LEADER]

FISHING = False
# ----- #
# --- WRITE ALL GAMES TO CSV --- #
#for GAME in GAMES: 
    #parseArenaToCSV(LOCATIONS_ARENA1,GAME,GENERATION,STARTERS,LEADERS,ARENA,FISHING,SPECIALPOKEMON_ARENA1)

# %%
# ---- ARENA-2 ---- #
POSSIBLE_TM_ARENA2 = POSSIBLE_TM_ARENA1 + ['11','4','12','1','34','25','45','19']
POSSIBLE_VM_ARENA2 = POSSIBLE_VM_ARENA1 + []
# ---- ARENA SETTINGS ---- #
ARENA = 'arena-2'
LOCATIONS_ARENA2 = LOCATIONS_ARENA1 + [
              {'name':'kanto-route-3', 'steps':placeholderSteps},
              {'name':'kanto-route-4', 'steps':placeholderSteps},
              {'name':'kanto-route-24', 'steps':placeholderSteps},
              {'name':'kanto-route-25', 'steps':placeholderSteps},
              {'name':'kanto-route-11', 'steps':placeholderSteps},
              {'name':'digletts-cave', 'steps':placeholderSteps}
             ]
SPECIALPOKEMON_ARENA2 = SPECIALPOKEMON_ARENA1 + ['kabuto','omanyte','magikarp','jynx']
#leader
staryu = {'name': 'staryu', 'level': 18, 'moves':['tackle','water-gun']}
starmie = {'name': 'starmie', 'level': 21, 'moves':['tackle','water-gun','bubble-beam','harden']}
LEADER = ('misty', [staryu,starmie])
LEADERS=[LEADER]

FISHING = False
# ----- #
# --- WRITE ALL GAMES TO CSV --- #
#for GAME in GAMES: 
    #parseArenaToCSV(LOCATIONS_ARENA2,GAME,GENERATION,STARTERS,LEADERS,ARENA,FISHING,SPECIALPOKEMON_ARENA)

# %%
# ---- ARENA-3 ---- #
POSSIBLE_TM_ARENA3 = POSSIBLE_TM_ARENA2 + ['28','24','8','44']
POSSIBLE_VM_ARENA3 = POSSIBLE_VM_ARENA2 + ['VM01 Zerschneider','VM05 Blitz']
# ---- ARENA SETTINGS ---- #
ARENA = 'arena-3'
LOCATIONS_ARENA3 = LOCATIONS_ARENA2 + [
              {'name':'kanto-route-5', 'steps':placeholderSteps},
              {'name':'kanto-route-6', 'steps':placeholderSteps},
              {'name':'ss-anne', 'steps':placeholderSteps},
             ]
SPECIALPOKEMON_ARENA3 = SPECIALPOKEMON_ARENA2 + ['farfetchd','mr-mime']
#leader
voltorb = {'name': 'voltorb', 'level': 21, 'moves':['tackle','screech','sonic-boom']}
pikachu = {'name': 'pikachu', 'level': 18, 'moves':['thunder-shock','growl','thunder-wave','quick-attack']}
raichu = {'name': 'raichu', 'level': 24, 'moves':['thunder-shock','growl','thunderbolt']}
LEADER = ('lt-surge', [voltorb,pikachu,raichu])
LEADERS=[LEADER]
FISHING = True
# ----- #
# --- WRITE ALL GAMES TO CSV --- #
#for GAME in GAMES: 
    #parseArenaToCSV(LOCATIONS_ARENA3,GAME,GENERATION,STARTERS,LEADERS,ARENA,FISHING,SPECIALPOKEMON_ARENA3)

# %%
# ---- ARENA-4 ---- #
POSSIBLE_TM_ARENA4 = POSSIBLE_TM_ARENA3 + ['30','13','48',
                                           '49','5','17',
                                           '33','2','7','18','10','15','41','50','23']
POSSIBLE_VM_ARENA4= POSSIBLE_VM_ARENA3 + ['VM02 Fliegen']
# ---- ARENA SETTINGS ---- #
ARENA = 'arena-4'
LOCATIONS_ARENA4 = LOCATIONS_ARENA3 + [
              {'name':'kanto-route-9', 'steps':placeholderSteps},
              {'name':'kanto-route-10', 'steps':placeholderSteps},
              {'name':'rock-tunnel', 'steps':placeholderSteps},
              {'name':'kanto-route-7', 'steps':placeholderSteps},
              {'name':'kanto-route-8', 'steps':placeholderSteps},
             ]
SPECIALPOKEMON_ARENA4 = SPECIALPOKEMON_ARENA3 + ['eevee']
#leader
victreebel = {'name': 'victreebel', 'level': 29, 'moves':['razor-leaf','wrap','poison-powder','sleep-powder']}
tangela = {'name': 'tangela', 'level': 24, 'moves':['constrict','bind']}
vileplume = {'name': 'vileplume', 'level': 29, 'moves':['petal-dance','poison-powder','mega-drain','sleep-powder']}
LEADER = ('erika', [victreebel,tangela,vileplume])
LEADERS=[LEADER]

FISHING = True
# ----- #
# --- WRITE ALL GAMES TO CSV --- #
#for GAME in GAMES: 
    #parseArenaToCSV(LOCATIONS_ARENA4,GAME,GENERATION,STARTERS,LEADERS,ARENA,FISHING,SPECIALPOKEMON_ARENA4)

# %%
# ---- ARENA-5 ---- #
POSSIBLE_TM_ARENA5 = POSSIBLE_TM_ARENA4 + ['21','40','32','37','16','39','42','20']
POSSIBLE_VM_ARENA5= POSSIBLE_VM_ARENA4 + ['VM03 Surfer', 'VM04 Stärke']
# ---- SETTINGS ---- #
ARENA = 'arena-5'
LOCATIONS_ARENA5 = LOCATIONS_ARENA4 + [{'name':'pokemon-tower', 'steps':placeholderSteps},
                                       {'name':'kanto-route-12', 'steps':placeholderSteps},
                                       {'name':'kanto-route-13', 'steps':placeholderSteps},
                                       {'name':'kanto-route-14', 'steps':placeholderSteps},
                                       {'name':'kanto-route-15', 'steps':placeholderSteps},
                                       {'name':'kanto-safari-zone', 'steps':placeholderSteps}
                                      ]
SPECIALPOKEMON_ARENA5 = SPECIALPOKEMON_ARENA4 + []
#leader
koffing = {'name': 'koffing', 'level': 37, 'moves':['tackle','smog','sludge','smokescreen']}
muk = {'name': 'muk', 'level': 39, 'moves':['disable','poison-gas','minimize','sludge']}
weezing = {'name': 'vileplume', 'level': 43, 'moves':['smog','sludge','toxic','self-destruct']}
LEADER = ('koga', [koffing,muk,koffing,weezing])
LEADERS=[LEADER]

FISHING = True
# ----- #
# --- WRITE ALL GAMES TO CSV --- #
#for GAME in GAMES: 
    #parseArenaToCSV(LOCATIONS_ARENA5,GAME,GENERATION,STARTERS,LEADERS,ARENA,FISHING,SPECIALPOKEMON_ARENA5)

# %%
# ---- ARENA-6 ---- #
POSSIBLE_TM_ARENA6 = POSSIBLE_TM_ARENA5 + ['6','36','9','3', '26' ]
POSSIBLE_VM_ARENA6= POSSIBLE_VM_ARENA5 + []
# ---- SETTINGS ---- #
ARENA = 'arena-6'
LOCATIONS_ARENA6 = LOCATIONS_ARENA5 + [
    {'name':'seafoam-islands', 'steps':placeholderSteps},
    {'name':'kanto-sea-route-19', 'steps':placeholderSteps},
    {'name':'kanto-sea-route-20', 'steps':placeholderSteps},
    {'name':'kanto-sea-route-21', 'steps':placeholderSteps},
    {'name':'power-plant', 'steps':placeholderSteps},
    {'name':'kanto-route-16', 'steps':placeholderSteps},
    {'name':'kanto-route-17', 'steps':placeholderSteps},
    {'name':'kanto-route-18', 'steps':placeholderSteps},
                                            ]
# IST ARKTOS,ZAPDOS DABEI ?
SPECIALPOKEMON_ARENA6 = SPECIALPOKEMON_ARENA5 + ['lapras']
#leader
kadabra = {'name': 'kadabra', 'level': 38, 'moves':['disable','recover','psybeam','psychic']}
mrMime = {'name': 'mr-mime', 'level': 37, 'moves':['confusion','barrier','light-screen','double-slap']}
venomoth = {'name': 'venomoth', 'level': 38, 'moves':['poison-powder','leech-life','stun-spore','psybeam']}
alakazam = {'name': 'alakazam', 'level': 43, 'moves':['psybeam','recover','psywave','reflect']}

LEADER = ('sabrina', [kadabra,mrMime,venomoth,alakazam])
LEADERS=[LEADER]

FISHING = True
# ----- #
# --- WRITE ALL GAMES TO CSV --- #
#for GAME in GAMES: 
    #parseArenaToCSV(LOCATIONS_ARENA6,GAME,GENERATION,STARTERS,LEADERS,ARENA,FISHING,SPECIALPOKEMON_ARENA6)

# %%
# ---- ARENA-7 ---- #
POSSIBLE_TM_ARENA7 = POSSIBLE_TM_ARENA6 + ['46','14','22','29','31','35']
POSSIBLE_VM_ARENA7= POSSIBLE_VM_ARENA6 + []
# ---- SETTINGS ---- #
ARENA = 'arena-7'
LOCATIONS_ARENA7 = LOCATIONS_ARENA6 + [
    {'name':'cinnabar-island', 'steps':placeholderSteps},
    {'name':'pokemon-mansion', 'steps':placeholderSteps},
]
SPECIALPOKEMON_ARENA7 = SPECIALPOKEMON_ARENA6 + []
#leader
growlithe = {'name': 'growlithe', 'level': 42, 'moves':['ember','leer','take-down','agility']}
ponyta = {'name': 'ponyta', 'level': 40, 'moves':['tail-whip','stomp','growl','fire-spin']}
rapidash = {'name': 'rapidash', 'level': 42, 'moves':['tail-whip','stomp','growl','fire-spin']}
arcanine = {'name': 'arcanine', 'level': 47, 'moves':['roar','ember','fire-blast','take-down']}
LEADER = ('blaine', [growlithe,ponyta,rapidash,arcanine])
LEADERS=[LEADER]
FISHING = True
# ----- #
# --- WRITE ALL GAMES TO CSV --- #
#for GAME in GAMES: 
    #parseArenaToCSV(LOCATIONS_ARENA7,GAME,GENERATION,STARTERS,LEADERS,ARENA,FISHING,SPECIALPOKEMON_ARENA7)

# %%
# ---- ARENA-8 ---- #
POSSIBLE_TM_ARENA8 = POSSIBLE_TM_ARENA7 + ['38']
POSSIBLE_VM_ARENA8= POSSIBLE_VM_ARENA7 + []
# ---- SETTINGS ---- #
ARENA = 'arena-8'
LOCATIONS_ARENA8 = LOCATIONS_ARENA7 + []
SPECIALPOKEMON_ARENA8 = SPECIALPOKEMON_ARENA7 + []
#leader
rhyhorn = {'name': 'rhyhorn', 'level': 45, 'moves':['stomp','tail-whip','fury-attack','horn-drill']}
dugtrio = {'name': 'dugtrio', 'level': 42, 'moves':['growl','dig','sand-attack','slash']}
nidoqueen = {'name': 'nidoqueen', 'level': 44, 'moves':['scratch','tail-whip','body-slam','poison-sting']}
nidoking = {'name': 'nidoking', 'level': 45, 'moves':['tackle','horn-attack','poison-sting','thrash']}
rhydon = {'name': 'rhydon', 'level': 50, 'moves':['stomp','tail-whip','fissure','horn-drill']}
LEADER = ('giovanni', [rhyhorn,dugtrio,nidoqueen,nidoking,rhydon])
LEADERS=[LEADER]
FISHING = True
# ----- #
# --- WRITE ALL GAMES TO CSV --- #
#for GAME in GAMES: 
    #parseArenaToCSV(LOCATIONS_ARENA8,GAME,GENERATION,STARTERS,LEADERS,ARENA,FISHING,SPECIALPOKEMON_ARENA8)

# %%
# TODO: TOP 4 ??
# ---- ARENA-9 ---- #
POSSIBLE_TM_ARENA9 = POSSIBLE_TM_ARENA8 + ['27','43','47']
POSSIBLE_VM_ARENA9= POSSIBLE_VM_ARENA8 + []
# ---- SETTINGS ---- #
ARENA = 'arena-9'
LOCATIONS_ARENA9 = LOCATIONS_ARENA8 + [
    {'name':'kanto-route-22', 'steps':placeholderSteps},
    {'name':'kanto-route-23', 'steps':placeholderSteps},
    {'name':'kanto-victory-road-2', 'steps':placeholderSteps},
   ]
SPECIALPOKEMON_ARENA9 = SPECIALPOKEMON_ARENA8 + []
FISHING = True
#leader 1 - LORELEI
dewgong = {'name': 'dewgong', 'level': 54, 'moves':['growl','aurora-beam','take-down','rest']}
cloyster = {'name': 'cloyster', 'level': 53, 'moves':['aurora-beam','supersonic','clamp','spike-cannon']}
slowbro = {'name': 'slowbro', 'level': 54, 'moves':['growl','water-gun','withdraw','amnesia']}
jynx = {'name': 'jynx', 'level':56, 'moves':['double-slap','ice-punch','body-slam','thrash']}
lapras = {'name': 'lapras', 'level': 50, 'moves':['body-slam','confuse-ray','blizzard','hydro-pump']}
LEADER1 = ('lorelei', [dewgong,cloyster,slowbro,jynx,lapras])
# ----- #
# ----- #
#leader 2 - BRUNO
onix1 = {'name': 'onix', 'level': 53, 'moves':['rock-throw','rage','slam','harden']}
hitmonchan = {'name': 'hitmonchan', 'level': 55, 'moves':['ice-punch','thunder-punch','mega-punch','counter']}
hitmonlee = {'name': 'hitmonlee', 'level': 55, 'moves':['jump-kick','focus-energy','high-jump-kick','mega-kick']}
onix2 = {'name': 'onix', 'level':56, 'moves':['rock-throw','rage','slam','harden']}
machamp = {'name': 'machamp', 'level': 58, 'moves':['leer','focus-energy','fissure','submission']}
LEADER2 = ('bruno', [onix1,hitmonchan,hitmonlee,onix2,machamp])
# ----- #
#leader 3 - AGATHA
gengar = {'name': 'gengar', 'level': 56, 'moves':['confuse-ray','night-shade','hypnosis','dream-eater']}
golbat = {'name': 'golbat', 'level': 56, 'moves':['supersonic','confuse-ray','wing-attack','haze']}
haunter = {'name': 'haunter', 'level': 55, 'moves':['confuse-ray','night-shade','hypnosis','dream-eater']}
arbok = {'name': 'arbok', 'level':58, 'moves':['bite','glare','screech','acid']}
gengar2 = {'name': 'gengar', 'level': 60, 'moves':['confuse-ray','night-shade','toxic','dream-eater']}
LEADER3 = ('agatha', [gengar,golbat,haunter,arbok,gengar2])
# ----- #
#leader 4 - LANCE
gyarados = {'name': 'gyarados', 'level': 58, 'moves':['hydro-pump','dragon-rage','leer','hyper-beam']}
dragonair = {'name': 'dragonair', 'level': 56, 'moves':['agility','slam','dragon-rage','hyper-beam']}
aerodactyl = {'name': 'aerodactyl', 'level':60, 'moves':['supersonic','bite','take-down','hyper-beam']}
dragonite = {'name': 'dragonite', 'level': 62, 'moves':['agility','slam','barrier','hyper-beam']}
LEADER4 = ('lance', [gyarados,dragonair,dragonair,aerodactyl,dragonite])
# ----- #
# CHAMP VARIANTS
pidgeot = {'name': 'pidgeot', 'level': 61, 'moves':['wing-attack','mirror-move','sky-attack','whirlwind']}
alakazam = {'name': 'alakazam', 'level': 59, 'moves':['psybeam','psychic','reflect','recover']}
rhydon = {'name': 'rhydon', 'level':61, 'moves':['leer','tail-whip','fury-attack','horn-drill']}
#leader 5 - BLUEBULBASAUR
exeggutor = {'name': 'exeggutor', 'level': 61, 'moves':['hypnosis','barrage','stomp']}
gyarados = {'name': 'gyarados', 'level': 63, 'moves':['dragon-rage','hydro-pump','hyper-beam','leer']}
charizard = {'name': 'charizard', 'level': 65, 'moves':['fire-blast','rage','slash','fire-spin']}
LEADER6_1 = ('blueBulbasaur', [pidgeot,alakazam,rhydon,exeggutor,gyarados,charizard])
# ----- #
#leader 5 - BLUECHARMANDER
exeggutor = {'name': 'exeggutor', 'level': 63, 'moves':['hypnosis','barrage','stomp']}
arcanine = {'name': 'arcanine', 'level': 61, 'moves':['roar','leer','ember','take-down']}
blastoise = {'name': 'blastoise', 'level': 65, 'moves':['hydro-pump','blizzard','bite','withdraw']}
LEADER6_2 = ('blueCharmander', [pidgeot,alakazam,rhydon,arcanine,exeggutor,blastoise])
# ----- #
#leader 5 - BLUESQUIRTLE
arcanine = {'name': 'arcanine', 'level': 63, 'moves':['roar','leer','ember','take-down']}
gyarados = {'name': 'gyarados', 'level': 61, 'moves':['dragon-rage','hydro-pump','hyper-beam','leer']}
venusaur = {'name': 'venusaur', 'level': 65, 'moves':['growth','mega-drain','razor-leaf','solar-beam']}
LEADER6_3 = ('blueSquirtle', [pidgeot,alakazam,rhydon,gyarados,arcanine,venusaur])
# ----- #
LEADERS = [LEADER1,LEADER2,LEADER3,LEADER4,LEADER6_1,LEADER6_2,LEADER6_3]
# --- WRITE ALL GAMES TO CSV --- #
for GAME in GAMES: 
    parseArenaToCSV(LOCATIONS_ARENA9,GAME,GENERATION,STARTERS,LEADERS,ARENA,FISHING,SPECIALPOKEMON_ARENA9)

# %%
machineArrays=[POSSIBLE_TM_ARENA1,POSSIBLE_TM_ARENA2,POSSIBLE_TM_ARENA3,POSSIBLE_TM_ARENA4,POSSIBLE_TM_ARENA5,POSSIBLE_TM_ARENA6,POSSIBLE_TM_ARENA7,POSSIBLE_TM_ARENA8,POSSIBLE_TM_ARENA9]
